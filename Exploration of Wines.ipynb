# %%
import pandas as pd
import numpy as np

data = pd.read_csv('winemag-data-130k-v2.csv')

# %%
data.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# ## Checking for Null Values

# %%
data.isnull().any()
# Out:
# Unnamed: 0               False
# country                   True
# description              False
# designation               True
# points                   False
# price                     True
# province                  True
# region_1                  True
# region_2                  True
# taster_name               True
# taster_twitter_handle     True
# title                    False
# variety                   True
# winery                   False
# dtype: bool

# %% [markdown]
# #### We can see that in the Many Columns  have null values.
#
# There are many techniques of dealing with the Missing values.
#
# 1.) Deleting the rows with missing values
#
# 2.) Replace with mean/median/mode.
#
# 3.) Assigning with Unique Category.
#
# In this I'm chosen the 3 techniques to deal with missing values.

# %%
def fill_missing_data(data):
    data.country.fillna(value = "Others", inplace = True)
    data.designation.fillna(value = "Not known", inplace = True)
    #data.price.fillna(value = "No description given", inplace = True)
    data.province.fillna(value = "Not given", inplace = True)
    data.region_1.fillna(value = "Not known", inplace = True)
    data.region_2.fillna(value = "Others", inplace = True)
    data.taster_name.fillna(value = "Not known", inplace = True)
    data.taster_twitter_handle.fillna(value = "Not given", inplace = True)
    data.variety .fillna(value="Others", inplace = True)
    return data

# %%
new_data = fill_missing_data(data)
print(np.shape(new_data))
new_data.head(5)
# Out:
# (129971, 14)
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                           Not known      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna             Others       Kerin O’Keefe
# 1            Not known             Others          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore             Others  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3             Not given  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
median = new_data["price"].median()
new_data["price"].fillna(median, inplace=True)

# %%
new_data.isnull().any()
# Out:
# Unnamed: 0               False
# country                  False
# description              False
# designation              False
# points                   False
# price                    False
# province                 False
# region_1                 False
# region_2                 False
# taster_name              False
# taster_twitter_handle    False
# title                    False
# variety                  False
# winery                   False
# dtype: bool

# %%
new_data.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87   25.0  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                           Not known      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna             Others       Kerin O’Keefe
# 1            Not known             Others          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore             Others  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3             Not given  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# I'm droping many columns as they didn't found usefull to me.

# %%
new_data.drop('region_1',inplace=True,axis=1)

# %%
new_data.drop('region_2',axis=1,inplace=True)

# %%
#new_data.drop('unnamed',axis=1)
new_data.drop('taster_name',axis=1,inplace=True)

# %%
new_data.drop('taster_twitter_handle',axis=1,inplace=True)

# %%
new_data.drop('province',axis=1,inplace=True)

# %%
new_data.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price  \
# 0                        Vulkà Bianco      87   25.0
# 1                            Avidagos      87   15.0
# 2                           Not known      87   14.0
# 3                Reserve Late Harvest      87   13.0
# 4  Vintner's Reserve Wild Child Block      87   65.0
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
count = new_data['variety'].value_counts()
count.tail(20)
# Out:
# Merlot-Grenache                 1
# Roussanne-Grenache Blanc        1
# Tempranillo-Tannat              1
# Teroldego Rotaliano             1
# Diamond                         1
# Bombino Nero                    1
# Tokay Pinot Gris                1
# Pinot Grigio-Sauvignon Blanc    1
# Merlot-Argaman                  1
# Kangoun                         1
# Pinot Blanc-Pinot Noir          1
# Tinta Madeira                   1
# Parraleta                       1
# Premsal                         1
# Zelen                           1
# Petit Courbu                    1
# Shiraz-Roussanne                1
# Piquepoul Blanc                 1
# Morava                          1
# Moschofilero-Chardonnay         1
# Name: variety, dtype: int64

# %%
data = new_data.groupby('variety').filter(lambda x: len(x) >100)

# %%
y = new_data['points'].values
X = new_data.drop(['points'], axis=1)
X.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  price                                          title  \
# 0  Vulkà Bianco   25.0              Nicosia 2013 Vulkà Bianco  (Etna)
# 1      Avidagos   15.0  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %% [markdown]
# ## Splitting data into Train and cross validation(or test): Stratified Sampling

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, stratify=y)
X_train, X_cv, y_train, y_cv = train_test_split(X_train, y_train, test_size=0.33, stratify=y_train)

# %% [markdown]
# ## Encoding Text feature: Description

# %%
from sklearn.feature_extraction.text import CountVectorizer

print(X_train.shape, y_train.shape)
print(X_cv.shape, y_cv.shape)
print(X_test.shape, y_test.shape)

print("="*100)


vectorizer_description = CountVectorizer(min_df=10,max_features=5000)
vectorizer_description.fit(X_train['description'].values) # fit has to happen only on train data

# we use the fitted CountVectorizer to convert the text to vector
X_train_description_bow = vectorizer_description.transform(X_train['description'].values)
X_cv_description_bow = vectorizer_description.transform(X_cv['description'].values)
X_test_description_bow = vectorizer_description.transform(X_test['description'].values)

print("After vectorizations")
print(X_train_description_bow.shape, y_train.shape)
print(X_cv_description_bow.shape, y_cv.shape)
print(X_test_description_bow.shape, y_test.shape)
print("="*100)
# Out:
# (58343, 8) (58343,)
# (28737, 8) (28737,)
# (42891, 8) (42891,)
# ====================================================================================================
# After vectorizations
# (58343, 5000) (58343,)
# (28737, 5000) (28737,)
# (42891, 5000) (42891,)
# ====================================================================================================

# %% [markdown]
# ## Encoding Categorical feature: Country

# %%
vectorizer_country = CountVectorizer()
vectorizer_country.fit(X_train['country'].values) # fit has to happen only on train data

# we use the fitted CountVectorizer to convert the text to vector
X_train_country_ohe = vectorizer_country.transform(X_train['country'].values)
X_cv_country_ohe = vectorizer_country.transform(X_cv['country'].values)
X_test_country_ohe = vectorizer_country.transform(X_test['country'].values)

print("After vectorizations")
print(X_train_country_ohe.shape, y_train.shape)
print(X_cv_country_ohe.shape, y_cv.shape)
print(X_test_country_ohe.shape, y_test.shape)
print(vectorizer_country.get_feature_names())
print("="*100)
# Out:
# After vectorizations
# (58343, 47) (58343,)
# (28737, 47) (28737,)
# (42891, 47) (42891,)
# ['africa', 'and', 'argentina', 'australia', 'austria', 'bosnia', 'brazil', 'bulgaria', 'canada', 'chile', 'china', 'croatia', 'cyprus', 'czech', 'egypt', 'england', 'france', 'georgia', 'germany', 'greece', 'herzegovina', 'hungary', 'india', 'israel', 'italy', 'lebanon', 'macedonia', 'mexico', 'moldova', 'morocco', 'new', 'others', 'peru', 'portugal', 'republic', 'romania', 'serbia', 'slovakia', 'slovenia', 'south', 'spain', 'switzerland', 'turkey', 'ukraine', 'uruguay', 'us', 'zealand']
# ====================================================================================================

# %% [markdown]
# ## Encoding Categorical feature: Designation

# %%
vectorizer_designation = CountVectorizer()
vectorizer_designation.fit(X_train['designation'].values) # fit has to happen only on train data

# we use the fitted CountVectorizer to convert the text to vector
X_train_designation_ohe = vectorizer_designation.transform(X_train['designation'].values)
X_cv_designation_ohe = vectorizer_designation.transform(X_cv['designation'].values)
X_test_designation_ohe = vectorizer_designation.transform(X_test['designation'].values)

print("After vectorizations")
print(X_train_designation_ohe.shape, y_train.shape)
print(X_cv_designation_ohe.shape, y_cv.shape)
print(X_test_designation_ohe.shape, y_test.shape)
print(vectorizer_designation.get_feature_names())
print("="*100)
# Out:
# After vectorizations
# (58343, 15967) (58343,)
# (28737, 15967) (28737,)
# (42891, 15967) (42891,)
# ['002', '006', '01', '02', '03', '05', '068', '075', '08', '09', '10', '100', '1000', '101', '1028', '1040', '107', '109', '10rf', '10th', '11', '1100', '1105', '113', '114', '1147', '1149', '115', '119', '1194', '12', '120', '121', '1265', '128', '13', '130', '1300', '138', '14', '140', '1423', '146', '149', '1492', '15', '150', '150th', '152', '154', '1550', '156', '16', '1607', '1614', '1619', '1628', '1637', '168', '1698', '17', '172', '1735', '174', '175', '1753', '1762', '1769', '1772', '178', '18', '181', '1810', '1827', '1836', '1840', '1844', '1850', '1860', '1865', '1866', '1868', '1869', '1872', '1875', '1879', '1880', '1887', '1888', '1894', '19', '1903', '1904', '1905', '1907', '1908', '1909', '1910', '1912', '1914', '1919', '1922', '1924', '1927', '1935', '1939', '1940', '1955', '1970', '1973', '1979', '198', '1988', '1998', '1b', '1er', '1rdrs4', '1st', '20', '200', '2000', '2003', '202', '204', '209', '20th', '21', '210', '2131', '22', '225', '229', '23', '234', '239', '24', '2401', '242', '24k', '25', '254', '25th', '26', '27', '278', '28', '287', '2900', '2a', '2bench', '2nd', '2t', '2v', '30', '300', '3055', '30th', '31', '310', '313', '314', '316', '318', '32', '320', '325', '33', '332', '337', '339', '34', '3400', '347', '348', '35', '35th', '36', '362', '363', '364', '369', '37', '375', '375ml', '38', '389', '39', '398', '3a', '3c', '3d', '3rd', '40', '400', '4040', '407', '408', '40th', '41', '412', '418', '424', '43', '439', '44', '446', '45', '451', '459', '45th', '46', '462', '464', '466', '47', '474', '47d', '48', '488', '49', '4990', '4b', '4m', '4or', '4sb20', '4th', '50', '500', '500ml', '502', '505', '50th', '51', '513', '518', '52', '520', '531', '533', '535', '55', '555', '56', '568', '57', '571', '59', '592', '596', '597', '5th', '60', '600', '6025', '603', '604', '605', '61', '618', '62', '624', '63', '6410', '642', '65', '650', '6600', '6666', '667', '67', '68', '69', '6n', '6th', '6ème', '70th', '72', '7200', '735', '750', '750ml', '76', '77', '777', '7th', '80', '800', '8000', '807', '809', '81', '815', '828', '84', '86', '877', '88', '89', '890', '898', '8b', '8mc', '90', '900', '907', '91', '91d', '92', '928', '93', '94', '946', '95', '96', '965', '970', '98', '99', '999', '99w', '9d', 'a252', 'a2o', 'a360p', 'a4', 'aaa', 'aatto', 'ab', 'aba', 'abacado', 'abadal', 'abades', 'abadia', 'abadía', 'abafado', 'abanico', 'abarca', 'abascal', 'abat', 'abate', 'abbandonato', 'abbaye', 'abbazia', 'abbey', 'abboccato', 'abbot', 'abbott', 'abbotts', 'abby', 'abbé', 'abbés', 'abeille', 'abeilles', 'abella', 'abellio', 'abercrombie', 'aberration', 'abetina', 'abigail', 'abime', 'abiqua', 'abondante', 'abracadabra', 'abreu', 'abrivat', 'abroachment', 'absidis', 'abstberg', 'abtei', 'abtsberg', 'abtsfronhof', 'abuelo', 'abymes', 'abélard', 'acadia', 'acantalys', 'accademia', 'acciaio', 'acciaiolo', 'acciderba', 'acclivi', 'acequias', 'acero', 'achelo', 'achille', 'achleiten', 'aciar', 'acin', 'acinatico', 'acinatium', 'acinum', 'aciprestes', 'aconcagua', 'acquagiusta', 'acquaintance', 'acquavigna', 'acquilae', 'acquisition', 'acre', 'acres', 'acróbata', 'acte', 'aculei', 'acusp', 'ad', 'adagio', 'adalfo', 'adama', 'adamado', 'adamus', 'adarmando', 'adaro', 'adastra', 'adda', 'adega', 'adelaide', 'adele', 'adeline', 'adenzia', 'adi', 'adige', 'adirondack', 'adler', 'adlum', 'adm', 'adn', 'adobe', 'adobo', 'adoli', 'adolsen', 'adornes', 'adour', 'adrian', 'adriane', 'adrianna', 'adriano', 'adriatico', 'adro', 'aduentus', 'adumim', 'adventures', 'adènzia', 'adèo', 'adélie', 'aegades', 'aegerter', 'ael', 'aeolia', 'aeolus', 'aeroplanservaj', 'aetneus', 'affected', 'affinato', 'affinity', 'afincado', 'after', 'afterglow', 'afternoon', 'afterthought', 'against', 'agamium', 'agassac', 'agata', 'agaves', 'age', 'aged', 'agent', 'agio', 'agiorgitiko', 'agioritikos', 'agios', 'agira', 'aglaea', 'aglianico', 'agnus', 'agnvs', 'agnès', 'agodinho', 'agoghè', 'agostini', 'agostino', 'agostón', 'agrario', 'agrelo', ' ...
# ====================================================================================================

# %% [markdown]
# ## Encoding Categorical feature: Title

# %%
vectorizer_title = CountVectorizer()
vectorizer_title.fit(X_train['title'].values) # fit has to happen only on train data

# we use the fitted CountVectorizer to convert the text to vector
X_train_title_ohe = vectorizer_title.transform(X_train['title'].values)
X_cv_title_ohe = vectorizer_title.transform(X_cv['title'].values)
X_test_title_ohe = vectorizer_title.transform(X_test['title'].values)

print("After vectorizations")
print(X_train_title_ohe.shape, y_train.shape)
print(X_cv_title_ohe.shape, y_cv.shape)
print(X_test_title_ohe.shape, y_test.shape)
print(vectorizer_title.get_feature_names())
print("="*100)
# Out:
# After vectorizations
# (58343, 26068) (58343,)
# (28737, 26068) (28737,)
# (42891, 26068) (42891,)
# ['002', '006', '01', '02', '03', '05', '068', '075', '08', '09', '10', '100', '1000', '101', '1028', '103', '1040', '107', '109', '10rf', '10span', '10th', '11', '1100', '1105', '113', '114', '1147', '1149', '115', '119', '1194', '12', '120', '121', '1265', '128', '12c', '13', '130', '1300', '138', '14', '140', '1423', '146', '149', '1492', '15', '150', '150th', '152', '154', '1550', '156', '16', '1607', '1614', '1619', '1628', '1637', '168', '1698', '17', '172', '1735', '174', '175', '1752', '1753', '1762', '1769', '1772', '178', '1789', '18', '181', '1810', '1827', '1836', '1840', '18401', '1844', '1845', '1848', '1850', '1852', '1856', '1860', '1865', '1866', '1868', '1869', '1870', '1872', '1875', '1877', '1879', '1880', '1882', '1887', '1888', '1894', '1898', '19', '1903', '1904', '1905', '1907', '1908', '1909', '1910', '1912', '1914', '1919', '1922', '1924', '1927', '1934', '1935', '1939', '1940', '1941', '1947', '1952', '1955', '1961', '1963', '1964', '1967', '1968', '1969', '1970', '1973', '1974', '1978', '1979', '198', '1984', '1985', '1986', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '1b', '1er', '1rdrs4', '1st', '20', '200', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '202', '204', '209', '20th', '21', '210', '2131', '22', '225', '229', '23', '234', '239', '24', '2401', '242', '24k', '25', '254', '25th', '26', '27', '278', '28', '287', '29', '2900', '2a', '2bench', '2hawk', '2nd', '2plank', '2t', '2v', '30', '300', '3055', '30th', '31', '310', '313', '314', '316', '318', '32', '320', '325', '33', '332', '337', '339', '34', '3400', '347', '348', '35', '351', '35th', '36', '360', '362', '363', '364', '369', '37', '375', '375ml', '38', '389', '39', '398', '3a', '3c', '3cv', '3d', '3fools', '3rd', '40', '400', '401k', '4040', '407', '408', '40th', '41', '412', '418', '42', '424', '43', '439', '44', '446', '45', '451', '459', '45th', '46', '460', '462', '464', '466', '46n118', '47', '474', '47d', '48', '488', '49', '4990', '4b', '4m', '4or', '4r4u', '4sb20', '4th', '50', '500', '500ml', '502', '505', '50th', '51', '513', '518', '52', '520', '531', '533', '535', '55', '555', '56', '568', '57', '571', '59', '592', '596', '597', '5os', '5th', '60', '600', '6025', '603', '604', '605', '61', '618', '62', '624', '63', '6410', '642', '65', '650', '6600', '6666', '667', '67', '68', '69', '6cepas6', '6n', '6th', '6ème', '70th', '72', '7200', '735', '75', '750', '750ml', '76', '77', '772', '777', '786', '7th', '80', '800', '8000', '807', '809', '81', '815', '828', '84', '86', '868', '877', '88', '89', '890', '898', '8b', '8mc', '90', '900', '907', '91', '91d', '92', '928', '93', '94', '946', '95', '96', '965', '970', '98', '99', '999', '99w', '9d', 'a252', 'a2o', 'a360p', 'a4', 'aaa', 'aarde', 'aaron', 'aatto', 'ab', 'aba', 'abacado', 'abacela', 'abad', 'abadal', 'abades', 'abadia', 'abadía', 'abafado', 'abanico', 'abarbanel', 'abarca', 'abascal', 'abat', 'abate', 'abbadia', 'abbandonato', 'abbaye', 'abbazia', 'abbey', 'abbeyville', 'abboccato', 'abbona', 'abbot', 'abbott', 'abbotts', 'abby', 'abbé', 'abbés', 'abeille', 'abeilles', 'abeja', 'abele', 'abelis', 'abella', 'abellio', 'abelé', 'abercrombie', 'aberrant', 'aberration', 'abetina', 'abigail', 'abime', 'abiouness', 'abiqua', 'abondante', 'abouriou', 'abracadabra', 'abraham', 'abrantes', 'abreu', 'abrigo', 'abrivat', 'abroachment', 'abruzzo', 'absidis', 'abstberg', 'abtei', 'abtsberg', 'abtsfronhof', 'abuelo', 'abymes', 'abélard', 'acacia', 'acadia', 'acaibo', 'acantalys', 'acate', 'accademia', 'accadia', 'acciaio', 'acciaiolo', 'acciderba', 'acclivi', 'accordini', 'accornero', 'acequias', 'acero', 'aces', 'achaia', 'achaval', 'achelo', 'achille', 'achleiten', 'aciar', 'acin', 'acinatico', 'acinatium', 'acinum', 'aciprestes', 'acker', 'ackerman', 'aconcagua', 'aconga', 'aconquija', 'acordeón', 'acorex', 'acorn', 'acquagiusta ...
# ====================================================================================================

# %% [markdown]
# ## Encoding Categorical feature: Variety

# %%
vectorizer_variety = CountVectorizer()
vectorizer_variety.fit(X_train['variety'].values) # fit has to happen only on train data

# we use the fitted CountVectorizer to convert the text to vector
X_train_variety_ohe = vectorizer_variety.transform(X_train['variety'].values)
X_cv_variety_ohe = vectorizer_variety.transform(X_cv['variety'].values)
X_test_variety_ohe = vectorizer_variety.transform(X_test['variety'].values)

print("After vectorizations")
print(X_train_variety_ohe.shape, y_train.shape)
print(X_cv_variety_ohe.shape, y_cv.shape)
print(X_test_variety_ohe.shape, y_test.shape)
print(vectorizer_variety.get_feature_names())
print("="*100)
# Out:
# After vectorizations
# (58343, 471) (58343,)
# (28737, 471) (28737,)
# (42891, 471) (42891,)
# ['abouriou', 'affile', 'agiorgitiko', 'aglianico', 'albana', 'albanello', 'albariño', 'albarossa', 'aleatico', 'alfrocheiro', 'alicante', 'aligoté', 'alsace', 'altesse', 'alvarelhão', 'alvarinho', 'and', 'angevine', 'ansonica', 'antão', 'apple', 'aragonez', 'aragonês', 'arinto', 'arneis', 'asprinio', 'assyrtico', 'assyrtiko', 'athiri', 'austrian', 'auxerrois', 'avesso', 'avola', 'azal', 'babić', 'bacchus', 'baco', 'baga', 'barbera', 'barroca', 'bastardo', 'bianca', 'bianco', 'bical', 'black', 'blanc', 'blanca', 'blanco', 'blatina', 'blauer', 'blaufränkisch', 'blend', 'bobal', 'bois', 'bombino', 'bonarda', 'bordeaux', 'bouschet', 'bovale', 'boğazkere', 'brachetto', 'braucol', 'bual', 'cabernet', 'canaiolo', 'candia', 'canelli', 'cannonau', 'cao', 'cappuccio', 'carignan', 'carignane', 'carignano', 'carineña', 'cariñena', 'carmenère', 'carricante', 'casavecchia', 'castelão', 'catarratto', 'cayuga', 'cerceal', 'cercial', 'cesanese', 'chambourcin', 'champagne', 'chancellor', 'charbono', 'chardonel', 'chardonnay', 'chasselas', 'chelois', 'chenin', 'chinuri', 'ciliegiolo', 'cinsault', 'clairette', 'claret', 'cococciola', 'coda', 'colombard', 'cortese', 'corvina', 'counoise', 'códega', 'de', 'debit', 'del', 'di', 'do', 'dolcetto', 'dornfelder', 'doña', 'du', 'duras', 'durella', 'durif', 'edelzwicker', 'ekigaïna', 'elbling', 'emir', 'encruzado', 'erbaluce', 'espadeiro', 'falanghina', 'favorita', 'fernão', 'feteasca', 'feteascǎ', 'fiano', 'fina', 'fino', 'franc', 'franca', 'francisca', 'frankovka', 'frappato', 'freisa', 'friulano', 'früburgunder', 'fumé', 'furmint', 'gaglioppo', 'gamay', 'gamza', 'garganega', 'garnacha', 'gelber', 'gentile', 'gewürztraminer', 'gialla', 'giallo', 'glera', 'godello', 'gomes', 'gouveio', 'graciano', 'gragnano', 'grains', 'grasparossa', 'grauburgunder', 'grecanico', 'grechetto', 'greco', 'grenache', 'grigio', 'grignolino', 'grillo', 'gris', 'groppello', 'gros', 'grosso', 'grüner', 'hamburg', 'hondarrabi', 'hárslevelü', 'incrocio', 'insolia', 'inzolia', 'istriana', 'jacquez', 'jacquère', 'jaen', 'johannisberg', 'kadarka', 'kalecik', 'karasakiz', 'karasi', 'kekfrankos', 'kerner', 'kinali', 'kisi', 'kotsifali', 'lagrein', 'lambrusco', 'larinho', 'laurent', 'lemberger', 'listán', 'lo', 'loin', 'loureiro', 'macabeo', 'madeira', 'madeleine', 'magliocco', 'malagousia', 'malagouzia', 'malbec', 'mali', 'malvar', 'malvasia', 'mandilaria', 'manseng', 'mantonico', 'manzoni', 'marawi', 'maria', 'marsanne', 'marselan', 'marzemino', 'mascalese', 'mataro', 'maturana', 'mauzac', 'mavrodaphne', 'mavrokalavryta', 'mavrotragano', 'mavroudi', 'mavrud', 'mazuelo', 'melnik', 'melon', 'mencía', 'meritage', 'merlot', 'meseguera', 'meslier', 'meunier', 'misket', 'mission', 'miúda', 'mole', 'molinara', 'monastrell', 'mondeuse', 'monica', 'montepulciano', 'monukka', 'morava', 'moravia', 'morillon', 'morio', 'moscadello', 'moscatel', 'moscato', 'moschofilero', 'mourvèdre', 'mtsvane', 'muscadelle', 'muscadine', 'muscat', 'muscatel', 'muskat', 'muskateller', 'musqué', 'müller', 'nacional', 'narince', 'nascetta', 'nasco', 'neagra', 'nebbiolo', 'negra', 'negrette', 'negro', 'negroamaro', 'nera', 'nerello', 'nero', 'neuburger', 'nielluciu', 'noir', 'norton', 'oeil', 'okuzgozu', 'ondenc', 'orange', 'orangetraube', 'others', 'ottonel', 'pais', 'pallagrello', 'palomino', 'pansa', 'papaskarasi', 'paralleda', 'passerina', 'país', 'pecorino', 'pedro', 'perricone', 'petit', 'petite', 'petits', 'pfeffer', 'picapoll', 'picolit', 'picpoul', 'picudo', 'piedirosso', 'pigato', 'pignoletto', 'pinot', 'pinotage', 'pires', 'plavac', 'plyto', 'port', 'portugieser', 'portuguese', 'posip', 'poulsard', 'prieto', 'primitivo', 'prié', 'prosecco', 'provence', 'prugnolo', 'prunelard', 'pugnitello', 'rabigato', 'raboso', 'ramisco', 'rara', 'rebula', 'red', 'refosco', 'regalǎ', 'rhône', 'ribolla', 'rieslaner', 'riesling', 'rivaner', 'rkatsiteli', 'robola', 'roditis', 'rolle', 'romorantin', 'românească', 'rondinella', 'roriz', 'rosa', 'rosado', 'rosato', 'rosenmuskat ...
# ====================================================================================================

# %% [markdown]
# ## Encoding Categorical feature: Winery

# %%
vectorizer_winery = CountVectorizer()
vectorizer_winery.fit(X_train['winery'].values) # fit has to happen only on train data

# we use the fitted CountVectorizer to convert the text to vector
X_train_winery_ohe = vectorizer_winery.transform(X_train['winery'].values)
X_cv_winery_ohe = vectorizer_winery.transform(X_cv['winery'].values)
X_test_winery_ohe = vectorizer_winery.transform(X_test['winery'].values)

print("After vectorizations")
print(X_train_winery_ohe.shape, y_train.shape)
print(X_cv_winery_ohe.shape, y_cv.shape)
print(X_test_winery_ohe.shape, y_test.shape)
print(vectorizer_winery.get_feature_names())
print("="*100)
# Out:
# After vectorizations
# (58343, 12837) (58343,)
# (28737, 12837) (28737,)
# (42891, 12837) (42891,)
# ['10', '100', '103', '10span', '12', '128', '12c', '14', '1492', '15', '154', '16', '1637', '1752', '1789', '18401', '1845', '1848', '1850', '1852', '1856', '1860', '1868', '1870', '1875', '1877', '1882', '1898', '1912', '21', '22', '24', '29', '2hawk', '2nd', '2plank', '32', '33', '35', '351', '36', '360', '38', '39', '3cv', '3fools', '401k', '41', '42', '44', '460', '46n118', '4r4u', '50', '52', '5os', '60', '6cepas6', '7200', '75', '772', '786', '800', '868', '88', '91', 'aaron', 'abacela', 'abad', 'abadia', 'abadía', 'abarbanel', 'abbadia', 'abbaye', 'abbazia', 'abbey', 'abbeyville', 'abbona', 'abbotts', 'abeja', 'abele', 'abelis', 'abella', 'abelé', 'aberrant', 'abiouness', 'abiqua', 'abraham', 'abrantes', 'abrigo', 'acacia', 'acaibo', 'acate', 'accadia', 'accordini', 'accornero', 'aces', 'achaia', 'achaval', 'acinum', 'aciprestes', 'acker', 'ackerman', 'aconcagua', 'aconga', 'aconquija', 'acordeón', 'acorex', 'acorn', 'acquaviva', 'acquiesce', 'acre', 'acres', 'acrobat', 'acronym', 'act', 'acumen', 'acón', 'acústic', 'ad', 'ada', 'adair', 'adam', 'adamant', 'adami', 'adams', 'adanti', 'adastra', 'addamo', 'addendum', 'adega', 'adegas', 'adelaida', 'adelaide', 'adelsheim', 'aderezo', 'adi', 'adige', 'adirondack', 'adler', 'admirable', 'adobe', 'adolf', 'adoquin', 'adriano', 'adrás', 'adèle', 'aegerter', 'aequorea', 'aether', 'africa', 'african', 'afrique', 'agassac', 'agata', 'agate', 'age', 'agel', 'ager', 'aglaea', 'aglan', 'agly', 'agnese', 'agnitio', 'agostina', 'agostino', 'agrapart', 'agrellos', 'agricola', 'agricole', 'agricoltori', 'agrinatura', 'agrisole', 'agro', 'agroargento', 'agros', 'agrícola', 'aguijón', 'aguirre', 'agustinos', 'agustí', 'agustín', 'ah', 'ahlgren', 'ahnfeldt', 'ai', 'aia', 'aidura', 'aigner', 'aiguilhe', 'aiken', 'aila', 'aimé', 'aione', 'air', 'airfield', 'airlie', 'aix', 'ajb', 'akarua', 'al', 'alain', 'alamos', 'alana', 'alanís', 'alarba', 'alario', 'alasia', 'alba', 'albada', 'albala', 'albali', 'albamar', 'alban', 'albano', 'albare', 'albarei', 'albas', 'albatreti', 'albatross', 'albeno', 'alberice', 'albert', 'alberta', 'alberti', 'albertina', 'alberto', 'albet', 'albino', 'albola', 'albrecht', 'albret', 'alcance', 'alcardet', 'alchemist', 'alconde', 'alcée', 'alda', 'aldea', 'aldegheri', 'alder', 'alderbrook', 'aldo', 'aldonia', 'alegra', 'alegre', 'alejandro', 'aleksander', 'alella', 'alene', 'alente', 'alentex', 'aleramici', 'aleramo', 'alesme', 'alessandria', 'alessandro', 'alessio', 'aletta', 'alex', 'alexana', 'alexander', 'alexandre', 'alexandria', 'alexis', 'alfasi', 'alfonso', 'alfred', 'alfredo', 'algodon', 'aliança', 'alias', 'alibert', 'alice', 'alicia', 'alidis', 'aligi', 'alion', 'alivu', 'alix', 'aliénor', 'aljibes', 'alkoomi', 'alla', 'allan', 'allandale', 'alle', 'allegrini', 'allen', 'allende', 'alleromb', 'alley', 'alliance', 'allimant', 'allora', 'alloro', 'allram', 'allure', 'allée', 'allégret', 'alma', 'almansa', 'almare', 'almaterra', 'almaviva', 'almerita', 'almez', 'almira', 'almonacid', 'almondo', 'almquist', 'aloft', 'alois', 'alonso', 'alorna', 'alpamanta', 'alpasión', 'alpataco', 'alpha', 'alphonse', 'alta', 'altaba', 'altadonna', 'altamana', 'altamira', 'altamura', 'altanuta', 'altas', 'altava', 'altavia', 'altavins', 'altaïr', 'altemasi', 'altemura', 'altenahr', 'altenburger', 'alter', 'alterra', 'altesino', 'althe', 'althéa', 'altimar', 'alto', 'altocedro', 'altolandon', 'altoona', 'altos', 'altozano', 'altvs', 'altùris', 'aluvé', 'alvarez', 'alvaro', 'alvear', 'alves', 'alvinte', 'alyris', 'alysian', 'alzinger', 'alzipratu', 'alzitana', 'am', 'ama', 'amadieu', 'amador', 'amadores', 'amalaya', 'amalia', 'amalie', 'amandi', 'amandine', 'amant', 'amanti', 'amantis', 'amapola', 'amarano', 'amaro', 'amastuola', 'amatore', 'amaurigue', 'amavi', 'amayna', 'ambasciata', 'ambassador', 'ambe', 'amberhill', 'ambiance', 'ambiente', 'ambition', 'ambo', 'ambra', 'ambrogio', 'ambrosini', 'ambyth', 'ameal', 'amelle', 'american', 'ames', 'amici', 'amicus', 'amie', 'ami ...
# ====================================================================================================

# %% [markdown]
# ## Encoding Numerical feature: Price

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()
# normalizer.fit(X_train['price'].values)
# this will rise an error Expected 2D array, got 1D array instead: 
# array=[105.22 215.96  96.01 ... 368.98  80.53 709.67].
# Reshape your data either using 
# array.reshape(-1, 1) if your data has a single feature 
# array.reshape(1, -1)  if it contains a single sample.
normalizer.fit(X_train['price'].values.reshape(1,-1))

X_train_price_norm = normalizer.transform(X_train['price'].values.reshape(1,-1))
X_cv_price_norm = normalizer.transform(X_cv['price'].values.reshape(1,-1))
X_test_price_norm = normalizer.transform(X_test['price'].values.reshape(1,-1))


print(X_train_price_norm[0:5])
print(X_train_price_norm.shape)
print(X_cv_price_norm[0:5])
print(X_cv_price_norm.shape)
print(X_test_price_norm[0:5])
print(X_test_price_norm.shape)

X_train_price_norm=X_train_price_norm.reshape(-1,1)
X_cv_price_norm=X_cv_price_norm.reshape(-1,1)
X_test_price_norm=X_test_price_norm.reshape(-1,1)
# Out:
# [[0.00248062 0.0104026  0.00112028 ... 0.00352088 0.0020005  0.004001  ]]
# (1, 58343)
# [[0.01544051 0.00076115 0.00163104 ... 0.00380576 0.0027184  0.0027184 ]]
# (1, 28737)
# [[0.0061229  0.00365546 0.00191912 ... 0.00228466 0.0020105  0.00118803]]
# (1, 42891)

# %% [markdown]
# ## Concatinating all the features

# %%
from scipy.sparse import hstack

X_tr = hstack((X_train_description_bow,X_train_country_ohe,X_train_designation_ohe,X_train_title_ohe,X_train_variety_ohe,X_train_winery_ohe,X_train_price_norm)).tocsr()

X_cr = hstack((X_cv_description_bow,X_cv_country_ohe,X_cv_designation_ohe,X_cv_title_ohe,X_cv_variety_ohe,X_cv_winery_ohe,X_cv_price_norm)).tocsr()

X_te = hstack((X_test_description_bow,X_test_country_ohe,X_test_designation_ohe,X_test_title_ohe,X_test_variety_ohe,X_test_winery_ohe,X_test_price_norm)).tocsr()


print("Final Data matrix")
print(X_tr.shape, y_train.shape)
print(X_cr.shape, y_cv.shape)
print(X_te.shape, y_test.shape)
print("="*100)
# Out:
# Final Data matrix
# (58343, 60391) (58343,)
# (28737, 60391) (28737,)
# (42891, 60391) (42891,)
# ====================================================================================================

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier(max_depth = 3)
clf = decision_tree.fit(X_tr ,y_train)

# %%
clf.score(X_tr ,y_train,sample_weight=None)
# Out:
# 0.17427969079409697

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
clf = SVC( gamma='auto')
clf.fit(X_tr ,y_train)
# Out:
# SVC(gamma='auto')

# %%
clf.score(X_tr ,y_train,sample_weight=None)
# Out:
# 0.13238948974169995

# %%
from prettytable import PrettyTable


x = PrettyTable()
x.field_names = ["Model", "Best score"]

x.add_row(["Decision tree", 0.1742 ])
x.add_row(["SVM",0.1323 ])

print(x)
# Out:
# +---------------+------------+
# |     Model     | Best score |
# +---------------+------------+
# | Decision tree |   0.1742   |
# |      SVM      |   0.1323   |
# +---------------+------------+
